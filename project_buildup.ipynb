# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing data into pandas dataframe

# %%
df = pd.read_fwf('https://www.minorplanetcenter.net/iau/MPCORB/MPCORB.DAT', skiprows = 40, comment = '--')
df
# Out:
#         Des'n    H     G  Epoch          M      Peri.       Node     Incl.  \
# 0         NaN  NaN   NaN    NaN        NaN        NaN        NaN       NaN
# 1       00001  3.4  0.15  K205V  162.68631   73.73161   80.28698  10.58862
# 2       00002  4.2  0.15  K205V  144.97567  310.20237  173.02474  34.83293
# 3       00003  5.2  0.15  K205V  125.43538  248.06618  169.85147  12.99105
# 4       00004  3.0  0.15  K205V  204.32771  150.87483  103.80908   7.14190
# ...       ...  ...   ...    ...        ...        ...        ...       ...
# 956848  PLS47  6.8  0.15  J609N    6.34474  348.97247    3.97611   4.42645
# 956849  PLS48  7.4  0.15  J609N  359.83375  350.08779   14.72089   6.93616
# 956850  PLS60  7.1  0.15  J609N  341.27760  195.31462  194.23889   5.97604
# 956851  T2S20  8.1  0.15  J739F  351.03715  198.04175  176.47369   0.72943
# 956852  T3S26  8.1  0.15  J77AO   18.49475  148.51129  204.50733   9.67977
#
#                e         n  ...  Reference #Obs #Opp        Arc   rms  \
# 0            NaN       NaN  ...        NaN       NaN        NaN   NaN
# 1       0.077557  0.214060  ...  MPO492748  6751 115  1801-2019  0.60
# 2       0.229972  0.213345  ...  MPO492748  8027 109  1821-2019  0.58
# 3       0.256936  0.226129  ...  MPO525910  7020 106  1821-2020  0.59
# 4       0.088516  0.271507  ...  MPO525910  6941 102  1821-2019  0.60
# ...          ...       ...  ...        ...       ...        ...   ...
# 956848  0.228200  0.199886  ...  Icarus 59    10   1     4 days   NaN
# 956849  0.241800  0.236911  ...  Icarus 59     7   1     4 days   NaN
# 956850  0.185815  0.286340  ...  MPO157547     6   1     4 days  0.59
# 956851  0.202185  0.270173  ...  MPC 14914     6   1     5 days   NaN
# 956852  0.258506  0.289642  ...  MPC 12545    13   1    10 days   NaN
#
#           Perts  Computer Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0           NaN       NaN         NaN         NaN         NaN         NaN
# 1       M-v 30h  Williams        0000         (1)       Ceres  20190915.0
# 2       M-v 28h  Williams        0000         (2)      Pallas  20190812.0
# 3       M-v 38h  Williams        0000         (3)        Juno  20200109.0
# 4       M-p 18h  Williams        0000         (4)       Vesta  20191229.0
# ...         ...       ...         ...         ...         ...         ...
# 956848      NaN    Herget        2000         NaN    4717 P-L  19600928.0
# 956849      NaN    Herget        2000         NaN    4847 P-L  19600928.0
# 956850      NaN      MPCW        2000         NaN    6013 P-L  19600928.0
# 956851      NaN     Green        2000         NaN    2060 T-2  19731004.0
# 956852      NaN  Bardwell        2000         NaN    2678 T-3  19771017.0
#
# [956853 rows x 22 columns]

# %%
# streamlining the data
mask1 = ~df['a'].isnull()
data = df[mask1].reset_index(drop=True)
data.rename(columns={'Unnamed: 20':'Name'}, inplace=True)
data
# Out:
#         Des'n    H     G  Epoch          M      Peri.       Node     Incl.  \
# 0       00001  3.4  0.15  K205V  162.68631   73.73161   80.28698  10.58862
# 1       00002  4.2  0.15  K205V  144.97567  310.20237  173.02474  34.83293
# 2       00003  5.2  0.15  K205V  125.43538  248.06618  169.85147  12.99105
# 3       00004  3.0  0.15  K205V  204.32771  150.87483  103.80908   7.14190
# 4       00005  6.9  0.15  K205V   17.84635  358.64840  141.57102   5.36742
# ...       ...  ...   ...    ...        ...        ...        ...       ...
# 956845  PLS47  6.8  0.15  J609N    6.34474  348.97247    3.97611   4.42645
# 956846  PLS48  7.4  0.15  J609N  359.83375  350.08779   14.72089   6.93616
# 956847  PLS60  7.1  0.15  J609N  341.27760  195.31462  194.23889   5.97604
# 956848  T2S20  8.1  0.15  J739F  351.03715  198.04175  176.47369   0.72943
# 956849  T3S26  8.1  0.15  J77AO   18.49475  148.51129  204.50733   9.67977
#
#                e         n  ...  Reference #Obs #Opp        Arc   rms  \
# 0       0.077557  0.214060  ...  MPO492748  6751 115  1801-2019  0.60
# 1       0.229972  0.213345  ...  MPO492748  8027 109  1821-2019  0.58
# 2       0.256936  0.226129  ...  MPO525910  7020 106  1821-2020  0.59
# 3       0.088516  0.271507  ...  MPO525910  6941 102  1821-2019  0.60
# 4       0.190913  0.238661  ...  MPO525910  2784  77  1845-2020  0.53
# ...          ...       ...  ...        ...       ...        ...   ...
# 956845  0.228200  0.199886  ...  Icarus 59    10   1     4 days   NaN
# 956846  0.241800  0.236911  ...  Icarus 59     7   1     4 days   NaN
# 956847  0.185815  0.286340  ...  MPO157547     6   1     4 days  0.59
# 956848  0.202185  0.270173  ...  MPC 14914     6   1     5 days   NaN
# 956849  0.258506  0.289642  ...  MPC 12545    13   1    10 days   NaN
#
#           Perts  Computer Unnamed: 18 Unnamed: 19      Name Unnamed: 21
# 0       M-v 30h  Williams        0000         (1)     Ceres  20190915.0
# 1       M-v 28h  Williams        0000         (2)    Pallas  20190812.0
# 2       M-v 38h  Williams        0000         (3)      Juno  20200109.0
# 3       M-p 18h  Williams        0000         (4)     Vesta  20191229.0
# 4       M-v 38h  Williams        0000         (5)   Astraea  20200105.0
# ...         ...       ...         ...         ...       ...         ...
# 956845      NaN    Herget        2000         NaN  4717 P-L  19600928.0
# 956846      NaN    Herget        2000         NaN  4847 P-L  19600928.0
# 956847      NaN      MPCW        2000         NaN  6013 P-L  19600928.0
# 956848      NaN     Green        2000         NaN  2060 T-2  19731004.0
# 956849      NaN  Bardwell        2000         NaN  2678 T-3  19771017.0
#
# [956850 rows x 22 columns]

# %% [markdown]
# ## Data plots

# %% [markdown]
# ### Scatter Plots of all the Asteroids

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

fig.set_size_inches(9,9)

fig.tight_layout()

ax.set_xlabel("semi-major axis")
ax.set_ylabel("eccentricity")
ax.set_zlabel("Inclination")

ax.set_xlim(0, 5.0)
ax.set_ylim(0.0, 1.0)
ax.set_zlim(0.0, 40.0)

x_a = data['a']
y_e = data['e']
z_I = data['Incl.']

ax.scatter(x_a, y_e, z_I, c = "Navy", s = 0.5);

ax.view_init(azim = -90, elev = 50)

# %% [markdown]
# ### Slice plots of 'a' vs 'e' and 'a' vs 'I'

# %%
fig,ax = plt.subplots(1,1)                    
fig.set_size_inches(11,8.5)                   

fig.tight_layout()                            

fig.suptitle('a vs e', fontsize = 20)
ax.set_xlim(1.5,4.5)
ax.set_ylim(0.0,0.6)

ax.set_xlabel("a (AU)")
ax.set_ylabel("e")
    
plt.plot(x_a, y_e, color='b', marker='o', linestyle='None', markersize=0.05)

# %%
fig,ax = plt.subplots(1,1)                    
fig.set_size_inches(11,8.5)                   

fig.tight_layout()                            

fig.suptitle('a vs I', fontsize = 20)
ax.set_xlim(1.5,4.5)
ax.set_ylim(0.0,40.0)

ax.set_xlabel("a (AU)")
ax.set_ylabel("I")
    
plt.plot(x_a, z_I, color='b', marker='o', linestyle='None', markersize=0.07)

# %% [markdown]
# ## 3D histogram of a, e and I

# %% [markdown]
# Focus on Main Belt Asteroids (1.5 < a < 5.5):

# %%
data1 = data.query('1.5 < a < 5.5')
array_3d = (data1['a'], data1['e'], data1['Incl.']) # x = a, y = e, z = I

# %%
H, [bx, by, bz] = np.histogramdd(array_3d, bins=100)
H.shape
# Out:
# (100, 100, 100)

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
def plot_semimajor_slice(idx):
    plt.imshow(H[idx,:,:], cmap=plt.cm.Blues)
    plt.colorbar();

interact(plot_semimajor_slice, idx = (0,99))
# Out:
# interactive(children=(IntSlider(value=49, description='idx', max=99), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_semimajor_slice(idx)>

# %%
def plot_ecc_slice(idx):
    plt.imshow(H[:,idx,:], cmap=plt.cm.Blues)
    plt.colorbar();

interact(plot_ecc_slice, idx = (0,99))
# Out:
# interactive(children=(IntSlider(value=49, description='idx', max=99), Output()), _dom_classes=('widget-interact',))
# <function __main__.plot_ecc_slice>

# %%
def plot_incl_slice(idx):
    plt.imshow(H[:,:,idx], cmap=plt.cm.Blues)
    plt.colorbar();

interact(plot_incl_slice, idx = (0,99))
# Out:
# interactive(children=(IntSlider(value=49, description='idx', max=99), Output()), _dom_classes=('widget-interact',))
# <function __main__.plot_incl_slice>

# %% [markdown]
# ## Inverse Transform Sampling

# %%
Fx = np.cumsum(H.flat)/np.sum(H)
plt.plot(Fx)

# %%
from numpy.random import rand
u = rand(1000000)
idx = np.searchsorted(Fx, u)
idx
# Out:
# array([390810, 270807, 392118, ..., 410612, 382503, 311815], dtype=int64)

# %%
fig, ax = plt.subplots(2,1)
fig.set_size_inches(11,8.5) 

fig.tight_layout()  

ax[0].hist(idx, bins=100);  

ax[1].plot(H.flat)

# %% [markdown]
# ### Converting the "flattened" indices in idx to (i, j, k) indices in 3D, and then to (a, e, I)

# %%
# i corresponds to a
i = (idx/10000).astype(int)         # width_y * width_z = 100 * 100 = 10000
i
# Out:
# array([39, 27, 39, ..., 41, 38, 31])

# %%
idx_yz = (idx % 10000).astype(int)
idx_yz
# Out:
# array([ 810,  807, 2118, ...,  612, 2503, 1815])

# %%
# j corresponds to e
j = (idx_yz/100).astype(int)        #width_y = 100
j
# Out:
# array([ 8,  8, 21, ...,  6, 25, 18])

# %%
# k corresponds to I
k = (idx_yz % 100).astype(int)

# %% [markdown]
# ### Changing the (i,j,k) indices into sampled values of (a,e,I)

# %%
width_a = bx[1] - bx[0]
a = bx[0] + ((i + rand(len(i))) * width_a)
a
# Out:
# array([3.08977032, 2.58395753, 3.09087385, ..., 3.17669514, 3.02784759,
#        2.77240788])

# %%
width_e = by[1] - by[0]
e = by[0] + ((j + rand(len(j))) * width_e)
e
# Out:
# array([0.08222165, 0.08408137, 0.21805229, ..., 0.06603064, 0.25013549,
#        0.18552375])

# %%
width_I = bz[1] - bz[0]
incl = bz[0] + ((k + rand(len(k))) * width_I)
incl
# Out:
# array([ 9.89362602,  7.0430135 , 18.31416296, ..., 12.36793504,
#         3.77633098, 15.35458671])

# %% [markdown]
# ### Tabling of the sampled values of (a,e,I)

# %%
idx_coord = []
for n, value in enumerate(idx):
    idx_coord.append((a[n],e[n],incl[n]))

# %% [markdown]
# ### Plotting the sampled parameters to see if they resemble original (real) data

# %%
fig,ax = plt.subplots(1,1)                    
fig.set_size_inches(11,8.5)                   

fig.tight_layout()                            

fig.suptitle('a vs I', fontsize = 20)
ax.set_xlim(1.5,4.5)
ax.set_ylim(0.0,40.0)

ax.set_xlabel("a (AU)")
ax.set_ylabel("I")
    
plt.plot(a, incl, color='b', marker='.', linestyle='None', markersize=0.07)

# %%
fig,ax = plt.subplots(1,1)                    
fig.set_size_inches(11,8.5)                   

fig.tight_layout()                            

fig.suptitle('a vs e', fontsize = 20)
ax.set_xlim(1.5,4.5)
ax.set_ylim(0.0,0.6)

ax.set_xlabel("a (AU)")
ax.set_ylabel("e")
    
plt.plot(a, e, color='b', marker='o', linestyle='None', markersize=0.05)

# %% [markdown]
# ##### Both plots seem to be somewhat close to the plots from the actual data. The sampled values are therefore close approximation to the actual values.

# %% [markdown]
# ### Saving the sampled parameters into .csv files

# %%
columns = ['a', 'e', 'incl']
df = pd.DataFrame(idx_coord,columns=columns)

# %%
df['a'].to_csv('a.csv',index=False)
df['e'].to_csv('e.csv',index=False)
df['incl'].to_csv('incl.csv',index=False)
